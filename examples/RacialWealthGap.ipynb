# %% [markdown]
# # Racial Wealth Gap

# %%
from __future__ import annotations

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from utilities import weighted_relplot, wmean_lineplot, wmedian_lineplot

sns.set_theme(context="paper")
sns.set_palette("gray")

# %%
df = pd.read_stata("../data/scf_processed.dta")
df.head()
# Out:
#            wgt  hhsex  age  agecl  edcl  married  lf  racecl  racecl4  \
# 0  6859.959728      2   35      2     2        2   1       1        1
# 1  7218.403805      2   35      2     2        2   1       1        1
# 2  6982.387611      2   35      2     2        2   1       1        1
# 3  7057.994966      2   35      2     2        2   1       1        1
# 4  6934.706832      2   35      2     2        2   1       1        1
#
#    racecl5  ...         racecl4_lbl         racecl5_lbl            race_lbl  \
# 0        1  ...  white non-Hispanic  white non-Hispanic  white non-Hispanic
# 1        1  ...  white non-Hispanic  white non-Hispanic  white non-Hispanic
# 2        1  ...  white non-Hispanic  white non-Hispanic  white non-Hispanic
# 3        1  ...  white non-Hispanic  white non-Hispanic  white non-Hispanic
# 4        1  ...  white non-Hispanic  white non-Hispanic  white non-Hispanic
#
#    age_lbl  equityfin  finincome  finmill  incomemill  incomethou  findeciles
# 0  (30-35]        NaN        0.0      0.0    0.012026   12.026084         0.0
# 1  (30-35]        NaN        0.0      0.0    0.012026   12.026084         0.0
# 2  (30-35]        NaN        0.0      0.0    0.012026   12.026084         0.0
# 3  (30-35]        NaN        0.0      0.0    0.012026   12.026084         0.0
# 4  (30-35]        NaN        0.0      0.0    0.012026   12.026084         0.0
#
# [5 rows x 58 columns]

# %%
filtered_df = df[
    (df["racecl4_lbl"] != "Other or Multiple race")
    & df["age"].between(21, 80)
    & (df["networth"] > 0)
    & (df["asset"] > 0)
    & (df["fin"] > 0)
    & (df["income"])
    & (df["equityfin"]).between(0, 1)
]

# %% [markdown]
# # The Racial Financial Wealth Gap

# %% [markdown]
# ## Weighted Average Household Financial Assets by Race and Year

# %%
# | label: racial-wealth-gap

lineplot = wmedian_lineplot(
    data=filtered_df,
    x="year",
    y="fin",
    weights="wgt",
    style="racecl4_lbl",
    # errorbar=True,
)

lineplot.set_title("Average Household Financial Assets by Race and Year")
lineplot.set_ylabel("Financial Assets (in $1,000s)")
lineplot.set_xlabel("Year")
lineplot.legend(title="Race")

# %%
lineplot = wmean_lineplot(
    data=filtered_df,
    x="year",
    y="fin",
    weights="wgt",
    style="racecl4_lbl",
    # errorbar=True,
)

lineplot.set_title("Average Household Financial Assets by Race and Year")
lineplot.set_ylabel("Financial Assets (in $1,000s)")
lineplot.set_xlabel("Year")
lineplot.legend(title="Race")

# %% [markdown]
# ## Weighted Average Household Financial Assets by Education, Race, and Year

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="year",
    y="fin",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %% [markdown]
# ## Weighted Average Household Normalized Financial Assets by Race and Year

# %%
plt.title("Average Household Normalized Financial Assets by Race and Year")
plt.ylabel("Financial Assets (in $1,000s)")
plt.xlabel("Year")

lineplot = wmean_lineplot(
    data=filtered_df,
    x="year",
    y="finincome",
    weights="wgt",
    style="racecl4_lbl",
)

plt.legend(title="Race")

# %% [markdown]
# ## Weighted Average Household Normalized Financial Assets by Education, Race, and Year

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="year",
    y="finincome",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %% [markdown]
# # Life Cycle Racial Financial Wealth Gap

# %% [markdown]
# ## Weighted Average Household Financial Assets by Race and Age Group

# %%
lineplot = wmean_lineplot(
    data=filtered_df,
    x="age_lbl",
    y="fin",
    weights="wgt",
    style="racecl4_lbl",
)

# %% [markdown]
# ## Weighted Average Household Financial Assets by Education, Race, and Age Group

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="age_lbl",
    y="fin",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %% [markdown]
# ## Weighted Average Household Normalized Financial Assets by Race and Age Group

# %%
lineplot = wmean_lineplot(
    data=filtered_df,
    x="age_lbl",
    y="finincome",
    weights="wgt",
    style="racecl4_lbl",
)

# %% [markdown]
# ## Weighted Average Household Normalized Financial Assets by Education, Race, and Age Group

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="age_lbl",
    y="finincome",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %% [markdown]
# # Life Cycle Racial Participation Gap

# %% [markdown]
# ## Weighted Household Participation by Race and Age Group

# %%
lineplot = wmean_lineplot(
    data=filtered_df,
    x="age_lbl",
    y="hequity",
    weights="wgt",
    style="racecl4_lbl",
)

# %% [markdown]
# ## Weighted Household Participation by Education, Race, and Age Group

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="age_lbl",
    y="hequity",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %%
lineplot = wmean_lineplot(
    data=filtered_df,
    x="findeciles",
    y="hequity",
    weights="wgt",
    style="racecl4_lbl",
)

plt.legend(title="Race")

# %%
lineplot = weighted_relplot(
    data=filtered_df,
    x="findeciles",
    y="hequity",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(

# %%
# | label: racial-wealth-gap
plt.title("Average Household Financial Assets by Race and Year")
plt.ylabel("Financial Assets (in $1,000s)")
plt.xlabel("Year")

lineplot = wmean_lineplot(
    data=filtered_df,
    x="findeciles",
    y="equity",
    weights="wgt",
    style="racecl4_lbl",
)

plt.legend(title="Race")

# %%
conditional_df = filtered_df[filtered_df["hequity"] == 1]

# %%
lineplot = wmean_lineplot(
    data=conditional_df,
    x="age_lbl",
    y="equityfin",
    weights="wgt",
    style="racecl4_lbl",
)

# %%
lineplot = weighted_relplot(
    data=conditional_df,
    x="age_lbl",
    y="equityfin",
    col="edcl_lbl",
    weights="wgt",
    style="racecl4_lbl",
)
# Out:
# /mnt/c/Users/alujan/GitHub/alanlujan91/ReturnsToWealthRWG/code/analysis/utilities.py:126: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   relplot = sns.relplot(
